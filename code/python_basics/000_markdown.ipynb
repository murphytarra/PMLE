# %% [markdown]
# # 🎉 Welcome to the Ultimate Jupyter Notebook Tutorial! 🎉
#
# In this notebook, we'll explore all the cool things you can do with Jupyter Notebooks! From text formatting to visualizations, and even interactive widgets, you'll learn it all here. Let's get started!

# %% [markdown]
# ## 🔤 Headings: Organize Like a Pro
#
# Headings are a great way to structure your notebook. Just use `#` for different heading levels.
#
# Here's how they look:
#
# # Heading 1 (Biggest!)
# ## Heading 2
# ### Heading 3
# #### Heading 4
#
# _Try writing your own heading below!_

# %% [markdown]
# # Insert heading here :)

# %% [markdown]
# ## ✨ Text Formatting: Make It Pop!
#
# Want to make something bold? **Use double asterisks!**
# Want italics? *Single asterisks do the trick!*
# Need both? ***Go wild with triple asterisks!***
#
# _Pro tip: Use formatting to highlight important notes in your analysis._

# %% [markdown]
# # Give it a try here :)

# %% [markdown]
# ## 🔢 Lists: Keep It Neat
#
# ### Bullet Points:
# - Point 1
# - Point 2
#   - Sub-point 2.1
#   - Sub-point 2.2
#
# ### Numbered Lists:
# 1. First
# 2. Second
# 3. Third
#
# _Lists are perfect for step-by-step instructions or summarizing findings._

# %% [markdown]
# # Make a list below of why you are an awesome person.
#
# eg
#
# Tara is awesome because:
# - She drinks the most tea in the NanoDTC
# - She makes a mean Lentil Dahl

# %% [markdown]
# ## 🔗 Links and Images: Spice Things Up
#
# Want to link to something cool? Use this format:
#
# [Click me to visit Google!](https://www.google.com)
#
# Add an image like this:
# ![Jupyter Logo](https://upload.wikimedia.org/wikipedia/commons/3/38/Jupyter_logo.svg)
#
# _Try adding a link or an image that inspires you!_

# %% [markdown]
# # Insert your link here :)

# %% [markdown]
# ## 🧮 Math Mode: For All You Math Geeks
#
# Jupyter Notebooks support LaTeX for writing equations. Just wrap your equations in `$` for inline math or `$$` for block math.
#
# - Inline: $E = mc^2$
# - Block:
#   $$\int_{-\infty}^{\infty} e^{-x^2} dx = \sqrt{\pi}$$
#
# _Math never looked so good!_

# %% [markdown]
# # What's your favourite formula?

# %% [markdown]
# ## 🧱 Code Blocks: Show Your Magic
#
# You can add code directly in Markdown for examples:
# `print("Hello World")`
#
# Or wrap it in triple backticks for a block:
# ```python
# def greet():
#     print("Hello, Jupyter!")
# greet()
# ```
#
# _Time to show off your coding chops!_

# %%
# 🚀 Python Code Cell: This is how you write Python code in a notebook 


import numpy as np
import matplotlib.pyplot as plt

# Generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot it
plt.plot(x, y, label='Sine Wave')
plt.title('A Simple Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

# %% [markdown]
# ## 📊 Tables: Keep It Tabular
#
# | Name   | Age | Role       |
# |--------|-----|------------|
# | Alice  | 25  | Scientist  |
# | Bob    | 30  | Engineer   |
# | Charlie| 22  | Designer   |
#
# _Tables are great for organizing data summaries._

# %% [markdown]
# # Make a table of all the people in the room with you below.

# %% [markdown]
# ## 🎛 Interactive Widgets: Make It Fun
#
# Widgets let you add interactivity to your notebooks! Try running the cell below to see an interactive slider in action:

# %%
from ipywidgets import interact

def square(x):
    return x ** 2

interact(square, x=(0, 10));
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=10), Output()), _dom_classes=('widget-interact',…

# %% [markdown]
# ## 📚 More Resources for the Basics :)
#
# Want to learn more about Jupyter Notebooks or Markdown? Check out these resources:
#
# - [Jupyter Notebook Documentation](https://jupyter-notebook.readthedocs.io/en/stable/)
# - [Markdown Guide](https://www.markdownguide.org/)

# %% [markdown]
# # Level up time! Advanced Notebook functionalities

# %% [markdown]
# ## 🪄 Magic Commands: Boost Productivity
#
# Jupyter comes with special commands called *magic commands*. These can help you run shell commands, time your code, or even change the behavior of your notebook.

# %%
# %%time: Time the execution of a cell
import time
start_time = time.time()
time.sleep(2)  # Simulate a 2-second task
print("Finished!")
print("Execution Time:", time.time() - start_time)
# Out:
# Finished!
# Execution Time: 2.001572847366333

# %%
# !: Run shell commands directly in the notebook
# !ls  # Lists files in your directory
# Out:
# 000_markdown.ipynb           005_advanced_functions.ipynb
# 001_syntacs.ipynb            006_oop.ipynb
# 002_inputs_and_outputs.ipynb 007_exception_handling.ipynb
# 003_datatypes.ipynb          008_filehandling.ipynb
# 004_functions.ipynb

# %% [markdown]
# ## 🎛 Dynamic Widgets: Control Parameters Easily
#
# You can use sliders, dropdowns, and more to interactively adjust parameters in your analysis.

# %%
import ipywidgets as widgets
from IPython.display import display

# Create sliders
slider = widgets.IntSlider(value=5, min=0, max=10, step=1, description="Slider:")
text_box = widgets.Text(value="Type here", description="Text Box:")

# Display widgets
display(slider, text_box)

# Use widget values dynamically
def update_slider(change):
    print(f"Slider value: {change['new']}")

slider.observe(update_slider, names='value')
# Out:
# IntSlider(value=5, description='Slider:', max=10)
# Text(value='Type here', description='Text Box:')
# Slider value: 6
# Slider value: 7
# Slider value: 8
# Slider value: 7
# Slider value: 5
# Slider value: 4
# Slider value: 3
# Slider value: 2
# Slider value: 1
# Slider value: 2
# Slider value: 3
# Slider value: 4
# Slider value: 5
# Slider value: 6
# Slider value: 7
# Slider value: 6
# Slider value: 5
# Slider value: 4
# Slider value: 3
# Slider value: 2

# %% [markdown]
# ## 📤 Export Your Notebook
#
# Did you know you can export this notebook to other formats like PDF or HTML? Use the command below in the terminal or Jupyter interface.

# %%
# !jupyter nbconvert --to html 000_markdown.ipynb
# Out:
# [NbConvertApp] Converting notebook 000_markdown.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 358972 bytes to 000_markdown.html

# %% [markdown]
# ## 🧮 Advanced Math in LaTeX
#
# Add detailed equations to explain complex concepts. Here's an example:
#
# $$\text{Fourier Transform:}\ \hat{f}(\xi) = \int_{-\infty}^{\infty} f(x) e^{-2\pi i x \xi} dx$$
#
# $$\text{Partial Differential Equation:}\ \frac{\partial u}{\partial t} = c^2 \nabla^2 u$$

# %% [markdown]
# ## 📊 DataFrame Styling: Make Tables Look Better
#
# Pandas lets you style your DataFrames for clear and beautiful displays.

# %%
import pandas as pd

# Example DataFrame
df = pd.DataFrame({
    "Experiment": ["A", "B", "C"],
    "Result": [0.85, 0.92, 0.88]
})

# Style DataFrame
df.style.background_gradient(cmap="coolwarm").set_caption("Styled DataFrame")
# Out:
# <style type="text/css">
# #T_87519_row0_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_87519_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_87519_row2_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# </style>
# <table id="T_87519">
#   <caption>Styled DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87519_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_87519_level0_col1" class="col_heading level0 col1" >Result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87519_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87519_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_87519_row0_col1" class="data row0 col1" >0.850000</td>
#     </tr>
#     <tr>
#       <th id="T_87519_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# ## 📽 Embedding Multimedia
#
# You can embed videos, audio files, or even GIFs directly into your notebook.
#
# ### Embed a YouTube Video
# [Click here for a video](https://www.youtube.com/watch?v=dQw4w9WgXcQ)

# %% [markdown]
# ## ✅ To-Do List for Data Analysis
#
# - [x] Load the data
# - [x] Clean the data
# - [ ] Perform analysis
# - [ ] Create visualizations
# - [ ] Write the report

# %% [markdown]
# ## 🔧 Running Shell Commands
#
# Run shell commands directly in the notebook for file handling or setup tasks.

# %%
# !mkdir data
# !echo "Hello, Jupyter!" > data/hello.txt
# !cat data/hello.txt
# Out:
# Hello, Jupyter!

# %% [markdown]
# ## 🗂 Widgets for File Uploads
#
# Let users upload files directly into the notebook.

# %%
uploader = widgets.FileUpload()
display(uploader)

# Access the uploaded file
def on_upload_change(change):
    for filename, content in uploader.value.items():
        print(f"Uploaded file: {filename}")

uploader.observe(on_upload_change, names='value')
# Out:
# FileUpload(value=(), description='Upload')

# %% [markdown]
# ## 🗺 Interactive Maps
#
# Use `folium` for interactive map visualizations.

# %%
import folium

# Create a map
m = folium.Map(location=[51.9522, 7.8497], zoom_start=13)

# Add a marker
folium.Marker([51.9522, 7.8497], popup="Somewhere in the middle of nowhere..").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
